# %%
import numpy as np
from mxnet import autograd,nd,init
import os

# %%
extension = '.txt'
for f in os.listdir("dataset/BTFN/1st_test/"):
    if not f.endswith(extension):
        print(f)
    #fp = os.path.join("dataset/BTFN/1st_test",f)
    #os.rename(fp,os.path.join("dataset/BTFN/1st_test",f+extension))

# %%
raw_data = []
for fn in os.listdir("dataset/BTFN/1st_test/"):
    if fn == '.ipynb_checkpoints.txt':
        pass
    else:
        with open(os.path.join("dataset/BTFN/1st_test/",fn),'r') as f:
            content = f.readlines()
    raw_data.append(content)

# %%
raw_data
# Out:
# ['-0.198\t0.178\t0.046\t-0.125\t-0.066\t-0.051\t-0.186\t-0.032\n',
#  '-0.356\t-0.032\t0.020\t0.063\t0.022\t-0.186\t-0.210\t-0.005\n',
#  '-0.171\t0.088\t-0.142\t-0.154\t0.005\t-0.073\t-0.186\t-0.017\n',
#  '0.183\t-0.039\t0.002\t-0.310\t-0.161\t-0.105\t-0.034\t-0.200\n',
#  '-0.039\t0.151\t-0.117\t-0.186\t-0.068\t-0.225\t-0.127\t-0.256\n',
#  '-0.391\t0.010\t-0.151\t-0.181\t0.000\t-0.176\t-0.095\t0.046\n',
#  '-0.330\t0.107\t-0.107\t-0.081\t0.000\t-0.068\t-0.190\t-0.012\n',
#  '-0.171\t-0.154\t-0.193\t-0.117\t-0.002\t-0.171\t-0.156\t-0.122\n',
#  '-0.142\t-0.164\t-0.149\t-0.122\t0.063\t0.129\t-0.020\t-0.034\n',
#  '-0.176\t-0.190\t-0.251\t-0.269\t-0.117\t0.017\t-0.002\t-0.222\n',
#  '-0.083\t-0.098\t-0.063\t-0.134\t-0.090\t-0.112\t-0.032\t-0.156\n',
#  '-0.242\t-0.115\t-0.132\t-0.188\t-0.127\t0.144\t-0.193\t-0.078\n',
#  '-0.176\t-0.046\t-0.103\t-0.081\t-0.220\t-0.068\t-0.149\t-0.137\n',
#  '-0.073\t-0.200\t-0.139\t-0.168\t0.173\t-0.176\t-0.181\t-0.278\n',
# ...
